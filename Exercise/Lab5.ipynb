# %% [markdown]
# ### РОССИЙСКИЙ УНИВЕРСИТЕТ ДРУЖБЫ НАРОДОВ
#
# #### Факультет физико-математических и естественных наук
# #### Кафедра информационных технологий

# %% [markdown]
# ## ОТЧЕТ ПО ЛАБОРАТОРНОЙ РАБОТЕ № 5
#
#
# ### Дисциплина: Методы машинного обучения

# %% [markdown]
# ##### Студент:  Яссин Мохамад Аламин
# ##### Группа:   НКНбд-01-20

# %% [markdown]
# ## Москва 2023
# ***

# %% [markdown]
# # Вариант №17
# Лабораторная работа 5

# %% [markdown]
# ## Текст задания:
#
# 1. Считайте котировки акции с указанным ниже тикером за 2020-2021 год:
#
#  TSM    Taiwan Semiconductor Manufacturing ADR
#
# 2. Показатель акции: дневная доходность, способ визуализации – эмпирическая PDF
#
# 3. Прогнозирование стоимости акции через 5 дней по данным за предыдущие 20 дней.
#
# 4. Показатель качества MSE
#
# 5. Техника борьбы с исчезающими градиентами:
#
#     Альтернативная инициализация весов

# %% [markdown]
# ## Решение:

# %%
from pandas_datareader import data as pdr
import yfinance as yfin
import datetime as dt
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. При помощи модуля `pandas_datareader` считайте котировки указанной в индивидуальным задании акции за указанный период времени.

# %%
yfin.pdr_override()

TSM = pdr.get_data_yahoo('TSM', 
                          start=dt.datetime(2020, 1, 1), 
                          end=dt.datetime(2021, 12, 31))
TSM.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  59.599998  60.119999  59.599998  60.040001  56.058460   8432600
# 2020-01-03  58.970001  58.980000  58.040001  58.060001  54.209759  10546400
# 2020-01-06  57.599998  57.689999  57.130001  57.389999  53.584194   8897200
# 2020-01-07  57.450001  58.599998  56.740002  58.320000  54.452518   7444300
# 2020-01-08  58.189999  58.980000  58.110001  58.750000  54.854004   5381500

# %% [markdown]
# ### 2. Визуализируйте котировки акции (столбец `Adj Close`) за весь период на графике. Подпишите оси и рисунок.

# %%
fig, ax = plt.subplots()
ax.plot(TSM['Adj Close'])
ax.grid(True)
ax.set_title("Котировки акций компании TSM в 2021-2022 гг.")
ax.set_xlabel('Time')
fig.autofmt_xdate(rotation=45)
ax.set_ylabel('Values')

#TSM['Close'].plot.line(grid=True,title='Котировки акций компании Apple в 2016-2022 гг.');
# Out:
# Text(0, 0.5, 'Values')

# %% [markdown]
# ### 3. Вычислите и визуализируйте заданный показатель акции в соответствии с индивидуальным заданием.
# дневная доходность, способ визуализации – эмпирическая PDF

# %%
d_close = TSM[['Adj Close']]
d_pct_ch2 = d_close / d_close.shift(1) - 1
d_pct_ch2 = d_pct_ch2.dropna()
d_pct_ch2
# Out:
#             Adj Close
# Date
# 2020-01-03  -0.032978
# 2020-01-06  -0.011540
# 2020-01-07   0.016205
# 2020-01-08   0.007373
# 2020-01-09   0.008170
# ...               ...
# 2021-12-23  -0.005111
# 2021-12-27   0.016739
# 2021-12-28  -0.005216
# 2021-12-29  -0.005325
# 2021-12-30  -0.008154
#
# [503 rows x 1 columns]

# %%
plt.figure(figsize=(10, 6))
plt.hist(d_pct_ch2['Adj Close'], bins=30, density=True, alpha=0.7)
plt.xlabel('Дата')
plt.ylabel('Дневная доходность')
plt.title('Эмпирическая дневная доходность акции PDF')
plt.grid(True)
plt.show()

# %%
pdf = d_pct_ch2.plot(kind='density')

# Настройка заголовка и осей
plt.title('Empirical Probability Density Function')
plt.xlabel('Daily Percentage Change')
plt.ylabel('Density')

plt.show()

# %% [markdown]
# ### 4. Сформируйте обучающую, тестовую и валидационные выборки для обучения нейронной сети в соответствии с индивидуальным заданием.

# %%
# Define parameters
sampling_rate = 1
sequence_length = 20
delay= 5
batch_size = 32

# Convert data to numpy arrays
raw_data = TSM['Adj Close'].values
targets = raw_data[delay:]

num_train_samples = int(0.5 * len(raw_data))
num_val_samples = int(0.25 * len(raw_data))
num_test_samples = len(raw_data) - num_train_samples - num_val_samples


mean = raw_data[:num_train_samples].mean(axis=0)
raw_data -= mean
std = raw_data[:num_train_samples].std(axis=0)
raw_data /= std # whole raw_data normalized w.r.t. first num_train_samples rows


raw_data=raw_data.reshape(-1, 1)
# Create training dataset
train_dataset = tf.keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],
    targets=targets,
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=0,
    end_index=num_train_samples
)

# Create validation dataset
val_dataset = tf.keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],
    targets=targets,
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=num_train_samples,
    end_index=num_train_samples + num_val_samples
)

# Create testing dataset
test_dataset = tf.keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],
    targets=targets,
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=num_train_samples + num_val_samples
)

# %% [markdown]
# ### 5. Постройте нейронную сеть MLP с нормализующим слоем и одним плотным скрытым слоем из 16 нейронов для прогнозирования стоимости акции и обучите ее на обучающей выборке. Оцените качество прогнозирования при помощи заданного показателя качества на тестовой выборке.

# %%
inputs = tf.keras.Input(shape=(sequence_length, 1))
x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.BatchNormalization()(x)  
x = tf.keras.layers.Dense(16, activation="relu")(x)
outputs = tf.keras.layers.Dense(1)(x)
model1 = tf.keras.Model(inputs, outputs)

model1.compile(optimizer="rmsprop", loss="mse")
history1 = model1.fit(train_dataset, epochs=50, validation_data=val_dataset)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 3s 76ms/step - loss: 0.0924 - val_loss: 0.0665
# Epoch 2/50
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0877 - val_loss: 0.5087
# Epoch 3/50
# 8/8 [==============================] - 1s 49ms/step - loss: 0.0481 - val_loss: 0.2553
# Epoch 4/50
# 8/8 [==============================] - 1s 60ms/step - loss: 0.0595 - val_loss: 0.3398
# Epoch 5/50
# 8/8 [==============================] - 1s 53ms/step - loss: 0.0629 - val_loss: 0.1651
# Epoch 6/50
# 8/8 [==============================] - 1s 65ms/step - loss: 0.0600 - val_loss: 0.0614
# Epoch 7/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0557 - val_loss: 0.0859
# Epoch 8/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0289 - val_loss: 0.2242
# Epoch 9/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0523 - val_loss: 0.4293
# Epoch 10/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0290 - val_loss: 0.1950
# Epoch 11/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0262 - val_loss: 0.1024
# Epoch 12/50
# 8/8 [==============================] - 1s 37ms/step - loss: 0.0518 - val_loss: 0.1569
# Epoch 13/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0371 - val_loss: 0.0785
# Epoch 14/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0479 - val_loss: 0.2263
# Epoch 15/50
# 8/8 [==============================] - 0s 27ms/step - loss: 0.0393 - val_loss: 0.0921
# Epoch 16/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0352 - val_loss: 0.2905
# Epoch 17/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0458 - val_loss: 0.0824
# Epoch 18/50
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0475 - val_loss: 0.0409
# Epoch 19/50
# 8/8 [==============================] - 1s 38ms/step - loss: 0.0286 - val_loss: 0.0336
# Epoch 20/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0331 - val_loss: 0.3759
# Epoch 21/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0409 - val_loss: 0.1675
# Epoch 22/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0341 - val_loss: 0.1196
# Epoch 23/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0397 - val_loss: 0.0336
# Epoch 24/50
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0488 - val_loss: 0.3390
# Epoch 25/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0500 - val_loss: 0.2127
# Epoch 26/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0346 - val_loss: 0.0384
# Epoch 27/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0470 - val_loss: 0.0289
# Epoch 28/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0351 - val_loss: 0.0495
# Epoch 29/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0379 - val_loss: 0.0443
# Epoch 30/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0468 - val_loss: 0.3367
# Epoch 31/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0405 - val_loss: 0.1575
# Epoch 32/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0315 - val_loss: 0.0211
# Epoch 33/50
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0483 - val_loss: 0.0194
# Epoch 34/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0351 - val_loss: 0.3745
# Epoch 35/50
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0265 - val_loss: 0.2212
# Epoch 36/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0638 - val_loss: 0.5845
# Epoch 37/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0602 - val_loss: 0.2631
# Epoch 38/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0516 - val_loss: 0.2135
# Epoch 39/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0473 - val_loss: 0.2965
# Epoch 40/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0247 - val_loss: 0.2367
# Epoch 41/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0442 - val_loss: 0.2420
# Epoch 42/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0361 - val_loss: 0.1199
# Epoch 43/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0586 - val_loss: 0.0830
# Epoch 44/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0445 - val_loss: 0.0349
# Epoch 45/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0300 - val_loss: 0.1642
# Epoch 46/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0390 - val_loss: 0.0336
# Epoch 47/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.0192
# Epoch 48/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0699 - val_loss: 0.2375
# Epoch 49/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0290 - val_loss: 0.2289
# Epoch 50/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0546 - val_loss: 0.0800

# %%
mse = model1.evaluate(test_dataset)
print("Mean Squared Error (MSE):", mse)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0532
# Mean Squared Error (MSE): 0.05323990061879158

# %%
loss = history1.history["loss"]
val_loss = history1.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, "bo", label="MSE на обучающей выборке")
plt.plot(epochs, val_loss, "b", label="MSE на валидационной выборке")
plt.title("Ошибка MSE на обучающей и валидационной выборках")
plt.legend();

# %% [markdown]
# ### 6. Примените указанную в индивидуальном задании технику решения проблемы исчезающих градиентов и постройте нейронную сеть MLP с нормализующим слоем и тремя плотными скрытыми слоями из 16 нейронов для прогнозирования стоимости акции и обучите ее на обучающей выборке. Оцените качество прогнозирования при помощи заданного показателя качества для тестовой выборки.

# %%
inputs = tf.keras.Input(shape=(sequence_length, 1))
x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.BatchNormalization()(x)  
x = tf.keras.layers.Dense(16, activation="relu",kernel_initializer="he_normal")(x)
x = tf.keras.layers.Dense(16, activation="relu",kernel_initializer="he_normal")(x)
x = tf.keras.layers.Dense(16, activation="relu",kernel_initializer="he_normal")(x)
outputs = tf.keras.layers.Dense(1)(x)
model2 = tf.keras.Model(inputs, outputs)

model2.compile(optimizer="rmsprop", loss="mse")
history2 = model2.fit(train_dataset, epochs=50, validation_data=val_dataset)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 26ms/step - loss: 0.1868 - val_loss: 1.1132
# Epoch 2/50
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0829 - val_loss: 0.3005
# Epoch 3/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0547 - val_loss: 0.2816
# Epoch 4/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1017 - val_loss: 0.2429
# Epoch 5/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0495 - val_loss: 0.2008
# Epoch 6/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0330 - val_loss: 0.1572
# Epoch 7/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0496 - val_loss: 0.5411
# Epoch 8/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0446 - val_loss: 0.2078
# Epoch 9/50
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0623 - val_loss: 0.2846
# Epoch 10/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0565 - val_loss: 0.1639
# Epoch 11/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0453 - val_loss: 0.2617
# Epoch 12/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0415 - val_loss: 0.4347
# Epoch 13/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0489 - val_loss: 0.0321
# Epoch 14/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0527 - val_loss: 0.0422
# Epoch 15/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0665 - val_loss: 0.2114
# Epoch 16/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0311 - val_loss: 0.0397
# Epoch 17/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0888 - val_loss: 0.5307
# Epoch 18/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0657 - val_loss: 0.0636
# Epoch 19/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0664 - val_loss: 0.1207
# Epoch 20/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0515 - val_loss: 0.0600
# Epoch 21/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0440 - val_loss: 0.0216
# Epoch 22/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0879 - val_loss: 0.0718
# Epoch 23/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0793 - val_loss: 0.1007
# Epoch 24/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0429 - val_loss: 0.0229
# Epoch 25/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0470 - val_loss: 0.4162
# Epoch 26/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0581 - val_loss: 0.3080
# Epoch 27/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0584 - val_loss: 0.0255
# Epoch 28/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0385 - val_loss: 0.0236
# Epoch 29/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0342 - val_loss: 0.0904
# Epoch 30/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0379 - val_loss: 0.1133
# Epoch 31/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0440 - val_loss: 0.0194
# Epoch 32/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0508 - val_loss: 0.0278
# Epoch 33/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0440 - val_loss: 0.0464
# Epoch 34/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0408 - val_loss: 0.2974
# Epoch 35/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0270 - val_loss: 0.0559
# Epoch 36/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.0569 - val_loss: 0.0941
# Epoch 37/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0363 - val_loss: 0.0449
# Epoch 38/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0277 - val_loss: 0.0778
# Epoch 39/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0435 - val_loss: 0.3641
# Epoch 40/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0698 - val_loss: 0.1335
# Epoch 41/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0414 - val_loss: 0.1617
# Epoch 42/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0421 - val_loss: 0.3660
# Epoch 43/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0735 - val_loss: 0.0457
# Epoch 44/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0162 - val_loss: 0.0286
# Epoch 45/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0410 - val_loss: 0.0304
# Epoch 46/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0448 - val_loss: 0.0830
# Epoch 47/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0321 - val_loss: 0.1656
# Epoch 48/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0559 - val_loss: 0.0986
# Epoch 49/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0346 - val_loss: 0.1294
# Epoch 50/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0234 - val_loss: 0.0405

# %%
mse = model2.evaluate(test_dataset)
print("Mean Squared Error (MSE):", mse)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0210
# Mean Squared Error (MSE): 0.020961448550224304

# %%
loss = history2.history["loss"]
val_loss = history2.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, "bo", label="MSE на обучающей выборке")
plt.plot(epochs, val_loss, "b", label="MSE на валидационной выборке")
plt.title("Ошибка MSE на обучающей и валидационной выборках")
plt.legend();

# %% [markdown]
# ### 7. Постройте рекуррентную нейронную сеть с нормализующим слоем и одним скрытым слоем LSTM из 16 нейронов для прогнозирования стоимости акции и обучите ее на обучающей выборке. Оцените качество прогнозирования при помощи заданного показателя качества на тестовой выборке.

# %%
inputs = tf.keras.Input(shape=(sequence_length, 1))
x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.BatchNormalization()(x)  
x = tf.keras.layers.LSTM(16)(inputs) 
outputs = tf.keras.layers.Dense(1)(x)
model3 = tf.keras.Model(inputs, outputs)

model3.compile(optimizer="rmsprop", loss="mse")
history3 = model3.fit(train_dataset,
                    epochs=50,
                    validation_data=val_dataset,
                   )
# Out:
# Epoch 1/50
# 8/8 [==============================] - 3s 90ms/step - loss: 0.7455 - val_loss: 7.5194
# Epoch 2/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4965 - val_loss: 6.3991
# Epoch 3/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3280 - val_loss: 5.4390
# Epoch 4/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1969 - val_loss: 4.6479
# Epoch 5/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1163 - val_loss: 3.9487
# Epoch 6/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0719 - val_loss: 3.4075
# Epoch 7/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0549 - val_loss: 2.9538
# Epoch 8/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0466 - val_loss: 2.6370
# Epoch 9/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0412 - val_loss: 2.3813
# Epoch 10/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0379 - val_loss: 2.1497
# Epoch 11/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0352 - val_loss: 2.1013
# Epoch 12/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0328 - val_loss: 2.0644
# Epoch 13/50
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0331 - val_loss: 1.7761
# Epoch 14/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0313 - val_loss: 1.7434
# Epoch 15/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0312 - val_loss: 1.6488
# Epoch 16/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0307 - val_loss: 1.5631
# Epoch 17/50
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0306 - val_loss: 1.6845
# Epoch 18/50
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0296 - val_loss: 1.6416
# Epoch 19/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0299 - val_loss: 1.6734
# Epoch 20/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0286 - val_loss: 1.4451
# Epoch 21/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0290 - val_loss: 1.4062
# Epoch 22/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0283 - val_loss: 1.5227
# Epoch 23/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0277 - val_loss: 1.4814
# Epoch 24/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0285 - val_loss: 1.5209
# Epoch 25/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0271 - val_loss: 1.4307
# Epoch 26/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0263 - val_loss: 1.4610
# Epoch 27/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0264 - val_loss: 1.2973
# Epoch 28/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0260 - val_loss: 1.5495
# Epoch 29/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0273 - val_loss: 1.2880
# Epoch 30/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0260 - val_loss: 1.2485
# Epoch 31/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0244 - val_loss: 1.3557
# Epoch 32/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0236 - val_loss: 1.0662
# Epoch 33/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0250 - val_loss: 1.2294
# Epoch 34/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0233 - val_loss: 1.2497
# Epoch 35/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0236 - val_loss: 1.1817
# Epoch 36/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0230 - val_loss: 1.2337
# Epoch 37/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0225 - val_loss: 1.1195
# Epoch 38/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0218 - val_loss: 1.1171
# Epoch 39/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0214 - val_loss: 1.0562
# Epoch 40/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0211 - val_loss: 1.0969
# Epoch 41/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0212 - val_loss: 1.0635
# Epoch 42/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0203 - val_loss: 1.1926
# Epoch 43/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0193 - val_loss: 1.0992
# Epoch 44/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0188 - val_loss: 1.0325
# Epoch 45/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0195 - val_loss: 1.1304
# Epoch 46/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0192 - val_loss: 1.2551
# Epoch 47/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0183 - val_loss: 1.1848
# Epoch 48/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0178 - val_loss: 1.1727
# Epoch 49/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0182 - val_loss: 1.0681
# Epoch 50/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0174 - val_loss: 1.2664

# %%
mse = model3.evaluate(test_dataset)
print("Mean Squared Error (MSE):", mse)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8362
# Mean Squared Error (MSE): 0.8362411856651306

# %% [markdown]
# ### 8. Визуализируйте кривые обучения для трех построенных моделей на одном рисунке в зависимости от эпохи обучения, подписывая оси и рисунок и создавая легенду. Используйте для визуализации относительную ошибку (ошибку обучения, деленную на начальную ошибку на первой эпохе).

# %%
import matplotlib.pyplot as plt

# Extract the training loss history for each model
model_1_train_loss = history1.history['loss']
model_2_train_loss = history2.history['loss']
model_3_train_loss = history3.history['loss']

# Calculate the relative training loss for each model
model_1_relative_loss = [loss / model_1_train_loss[0] for loss in model_1_train_loss]
model_2_relative_loss = [loss / model_2_train_loss[0] for loss in model_2_train_loss]
model_3_relative_loss = [loss / model_3_train_loss[0] for loss in model_3_train_loss]

# Plot the learning curves
epochs = range(1, len(model_1_train_loss) + 1)
plt.plot(epochs, model_1_relative_loss, label='Model 1')
plt.plot(epochs, model_2_relative_loss, label='Model 2')
plt.plot(epochs, model_3_relative_loss, label='Model 3')

# Set plot labels and legend
plt.xlabel('Epochs')
plt.ylabel('Relative Training Loss')
plt.title('Learning Curves')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### 9. Визуализируйте весь набор данных и прогнозы трех построенных моделей для обучающей и тестовой выборок на одном рисунке (ось X – даты, ось Y – стоимость акции), подписывая оси и рисунок и создавая легенду.

# %%
# Get the original data
dates = TSM.index
actual_data = TSM['Adj Close']

# Get the predictions for each model on the test set
model_1_predictions_test = model1.predict(test_dataset).reshape(-1)
model_2_predictions_test = model2.predict(test_dataset).reshape(-1)
model_3_predictions_test = model3.predict(test_dataset).reshape(-1)

# Get the predictions for each model on the training set
model_1_predictions_train = model1.predict(train_dataset).reshape(-1)
model_2_predictions_train = model2.predict(train_dataset).reshape(-1)
model_3_predictions_train = model3.predict(train_dataset).reshape(-1)

# Create a new figure
plt.figure(figsize=(15, 10))

# Plot the entire dataset
plt.plot(dates[-len(model_1_predictions_train):], actual_data[:len(model_1_predictions_train)], label='Actual Data')

# Plot the predictions for each model on the test set
plt.plot(dates[-len(model_1_predictions_test):], model_1_predictions_test, label='Model 1 Predictions on Test')
plt.plot(dates[-len(model_2_predictions_test):], model_2_predictions_test, label='Model 2 Predictions on Test')
plt.plot(dates[-len(model_3_predictions_test):], model_3_predictions_test, label='Model 3 Predictions on Test')

# Plot the predictions for each model on the training set
plt.plot(dates[-len(model_1_predictions_train):], model_1_predictions_train, label='Model 1 Predictions on Train')
plt.plot(dates[-len(model_2_predictions_train):], model_2_predictions_train, label='Model 2 Predictions on Train')
plt.plot(dates[-len(model_3_predictions_train):], model_3_predictions_train, label='Model 3 Predictions on Train')

# Set plot labels and legend
plt.title('Stock Price Predictions')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()

# Show the plot
plt.show()

# Create a new figure
plt.figure(figsize=(15, 10))

#printing the last section of the dataset
plt.plot(dates[-len(model_1_predictions_test):], actual_data[:len(model_1_predictions_test)], label='Actual Data')
plt.plot(dates[-len(model_1_predictions_test):], model_1_predictions_test, label='Model 1 Predictions on Test')
plt.plot(dates[-len(model_2_predictions_test):], model_2_predictions_test, label='Model 2 Predictions on Test')
plt.plot(dates[-len(model_3_predictions_test):], model_3_predictions_test, label='Model 3 Predictions on Test')
plt.plot(dates[-len(model_1_predictions_test):], model_1_predictions_train[:len(model_1_predictions_test)], label='Model 1 Predictions on Train')
plt.plot(dates[-len(model_1_predictions_test):], model_2_predictions_train[:len(model_1_predictions_test)], label='Model 2 Predictions on Train')
plt.plot(dates[-len(model_1_predictions_test):], model_3_predictions_train[:len(model_1_predictions_test)], label='Model 3 Predictions on Train')

# Set plot labels and legend
plt.title('Stock Price Predictions')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()

# Show the plot
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 1s 6ms/step
# 8/8 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 5ms/step
